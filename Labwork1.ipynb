# %%
pip install numpy matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 10.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 9.5 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 8.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 9.1 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

# %%
def read_column_as_numpy(filename, column_name):
    with open(filename, newline='', encoding='utf-8') as csvfile:
        reader = csv.reader(csvfile)
        headers = next(reader)
        column_index = headers.index(column_name)
        data = [row[column_index] for row in reader if row[column_index].isdigit()]
        return np.array(data, dtype=int)

# %%
filename = 'russia_losses_equipment.csv'
column_name = 'aircraft'

# Зчитуємо дані з файлу
aircraft_losses = read_column_as_numpy(filename, column_name)

# %%
daily_losses = aircraft_losses

# %%
top_3_losses = np.sort(daily_losses)[-3:]
print("Top 3 highest daily losses:", top_3_losses)
# Out:
# Top 3 highest daily losses: [369 369 369]

# %%
total_losses_since_summer_2022 = np.sum(daily_losses[180:])
print("Total losses since summer 2022:", total_losses_since_summer_2022)
# Out:
# Total losses since summer 2022: 206864

# %%
average_losses_last_300_days = np.mean(daily_losses[-300:])
print("Average losses in the last 300 days:", average_losses_last_300_days)
# Out:
# Average losses in the last 300 days: 213.57333333333332

# %%
plt.figure(figsize=(8, 16), dpi=100)
plt.plot(daily_losses, linestyle='-', marker='o', label='Daily Aircraft Losses')
plt.title('Aircraft Losses Over Time')
plt.xlabel('Days since start of the war')
plt.ylabel('Number of Aircraft Lost')
plt.grid(True)
plt.legend()
plt.savefig('aircraft_losses.png', format='png')
plt.show()
